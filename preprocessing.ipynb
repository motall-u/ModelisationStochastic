# %%
import pandas as pd
import os
import numpy as np

# %%
data_path = "datasets/data Vanad/data Vanad"

# %%
act1 = pd.read_csv(data_path+"/activity-2014-01.csv")

# %%
call1 = pd.read_csv(data_path+"/calls-2014-02.csv")

# %%
call1.head()
# Out:
#          date_received  queue_name  agent_number             answered consult  \
# 0  2014-02-01 09:00:37       30560        6975.0  2014-02-01 09:00:38     NaN
# 1  2014-02-01 09:04:18       30175        6985.0  2014-02-01 09:04:19     NaN
# 2  2014-02-01 09:08:43       30175        7531.0  2014-02-01 09:08:44     NaN
# 3  2014-02-01 09:08:54       30560        9109.0  2014-02-01 09:08:55     NaN
# 4  2014-02-01 09:09:08       30175        6985.0  2014-02-01 09:09:09     NaN
#
#   transfer               hangup
# 0      NaN  2014-02-01 09:05:52
# 1      NaN  2014-02-01 09:07:00
# 2      NaN  2014-02-01 09:09:05
# 3      NaN  2014-02-01 09:13:31
# 4      NaN  2014-02-01 09:12:55

# %%
act1[act1['dnd_id'] ==3]
# Out:
#               id  user_id  dnd_id  campaign_id  extension  last_call_id  \
# 10      20015891     5094       3          622       1137             0
# 12      20015900     5099       3          622       1118             0
# 13      20015903     7566       3          622       7150             0
# 14      20015904     5127       3          622       1123             0
# 15      20015908     7565       3          622       7152             0
# ...          ...      ...     ...          ...        ...           ...
# 140693  20722093     6664       3          622       1131      11165830
# 140695  20722195     6664       3          622       1131      11165978
# 140697  20722292     6664       3          622       1131      11166029
# 140699  20722390     6664       3          622       1131      11166081
# 140701  20722418     6664       3          622       1131      11166082
#
#         startdatetime    enddatetime  agent_id
# 10       1/2/14 07:58   1/2/14 08:18      6935
# ...

# %%
acti_used_var = ["id","startdatetime","enddatetime","agent_id"]
call_used_var = ["date_received","queue_name","agent_number","answered","hangup"]

# %%
acti_new_col = ["Activity_id","StartTime","EndTime","AgentID"]
call_new_col = ["CallArrivalTime","ServiceID","AgentID","AnsweredTime","CallDepartureTime"]

# %%
act_1 = act1[acti_used_var]
call_1 = call1[call_used_var]

# %%
act_1.columns = acti_used_var
call_1.columns = call_new_col

# %%
np.unique(call_1[call_1['AgentID']==6975]['ServiceID'])
# Out:
# array([30066, 30172, 30175, 30179, 30181, 30511, 30519, 30560])

# %%
act_1[act_1["agent_id"]==8189]
# Out:
#               id  startdatetime    enddatetime  agent_id
# 0       20015827   1/2/14 07:18   1/2/14 08:00      8189
# 18      20015922   1/2/14 08:00   1/2/14 08:19      8189
# 39      20016052   1/2/14 08:19   1/2/14 08:20      8189
# 40      20016053   1/2/14 08:20   1/2/14 08:21      8189
# 47      20016073   1/2/14 08:21   1/2/14 08:34      8189
# ...          ...            ...            ...       ...
# 137682  20704520  1/31/14 11:53  1/31/14 11:59      8189
# 137793  20704822  1/31/14 11:59  1/31/14 11:59      8189
# 137794  20704823  1/31/14 11:59  1/31/14 12:02      8189
# 137856  20705011  1/31/14 12:02  1/31/14 12:02      8189
# 137857  20705014  1/31/14 12:02  1/31/14 12:02      8189
#
# [1525 rows x 4 columns]

# %%
#On recupere les 8 services demandes
height_services = list(call_1['ServiceID'].value_counts().index)[:8]

# %%
height_services
# Out:
# [30175, 30560, 30172, 30181, 30179, 30066, 30241, 30584]

# %%
boolean_series = call_1.ServiceID.isin(height_services)
final_call1 = call1[boolean_series]

# %%
final_call1.shape
# Out:
# (112996, 7)

# %%
call_1.shape
# Out:
# (113945, 5)

# %%
def get_height_service(path,file_name,save_to):
    if not os.path.exists(save_to):
        os.makedirs(save_to)
    call1_ = pd.read_csv(path+"/"+ file_name)
    call_used_var_ = ["date_received","queue_name","agent_number","answered","hangup"]
    call_new_col_ = ["CallArrivalTime","ServiceID","AgentID","AnsweredTime","CallDepartureTime"]
    call_1_ = call1[call_used_var_]
    call_1_.columns = call_new_col_
    #On recupere les 8 services demandes
    height_services = list(call_1_['ServiceID'].value_counts().index)[:8]
    boolean_series = call_1_.ServiceID.isin(height_services)
    call_1_ = call_1_[boolean_series]
    call_1_.to_csv(save_to+"/"+file_name,index=False)

# %%
get_height_service(data_path,"calls-2014-02.csv","FinalData")

# %%
# !ls
# Out:
#  calls-2014-01		      datasets	  Tp_HomeWork-1.R
#  calls-2014-02.csv	      f		  TravailFinalDIC2.pdf
#  calls-2014-02.csvfinal       FinalData  'Untitled Folder'
#  calls-2014-02.csvfinal.csv   nouveau	  Untitled.ipynb
#  cours			      thesis

# %%
pd.read_csv("calls-2014-02.csv")
# Out:
#             CallArrivalTime  ServiceID  AgentID         AnsweredTime  \
# 0       2014-02-01 09:00:37      30560   6975.0  2014-02-01 09:00:38
# 1       2014-02-01 09:04:18      30175   6985.0  2014-02-01 09:04:19
# 2       2014-02-01 09:08:43      30175   7531.0  2014-02-01 09:08:44
# 3       2014-02-01 09:08:54      30560   9109.0  2014-02-01 09:08:55
# 4       2014-02-01 09:09:08      30175   6985.0  2014-02-01 09:09:09
# ...                     ...        ...      ...                  ...
# 112991  2014-02-28 19:57:17      30584   6934.0  2014-02-28 19:57:18
# 112992  2014-02-28 19:58:44      30584   6949.0  2014-02-28 19:58:44
# 112993  2014-02-28 19:59:08      30584   6934.0  2014-02-28 19:59:09
# 112994  2014-02-28 19:59:16      30584   6949.0  2014-02-28 19:59:17
# 112995  2014-02-28 20:00:03      30584   6949.0  2014-02-28 20:00:04
#
#           CallDepartureTime
# 0       2014-02-01 09:05:52
# 1       2014-02-01 09:07:00
# 2       2014-02-01 09:09:05
# ...

# %%
filenames = ['calls-2014-01.csv',
 'calls-2014-02.csv',
 'calls-2014-03.csv',
 'calls-2014-04.csv',
 'calls-2014-05.csv',
 'calls-2014-06.csv',
 'calls-2014-07.csv',
 'calls-2014-08.csv',
 'calls-2014-09.csv',
  'calls-2014-10.csv',
  'calls-2014-11.csv',
  'calls-2014-12.csv'
]

# %%
for path_ in filenames:
    get_height_service(data_path,path_,"FinalData")

# %%
filenames
# Out:
# ['calls-2014-01.csv',
#  'calls-2014-02.csv',
#  'calls-2014-03.csv',
#  'calls-2014-04.csv',
#  'calls-2014-05.csv',
#  'calls-2014-06.csv',
#  'calls-2014-07.csv',
#  'calls-2014-08.csv',
#  'calls-2014-09.csv',
#  'calls-2014-10.csv',
#  'calls-2014-11.csv',
#  'calls-2014-12.csv']

# %%
#split by day now
t = pd.read_csv("calls-2014-02.csv")

# %%
t[:5]
# Out:
#        CallArrivalTime  ServiceID  AgentID         AnsweredTime  \
# 0  2014-02-01 09:00:37      30560   6975.0  2014-02-01 09:00:38
# 1  2014-02-01 09:04:18      30175   6985.0  2014-02-01 09:04:19
# 2  2014-02-01 09:08:43      30175   7531.0  2014-02-01 09:08:44
# 3  2014-02-01 09:08:54      30560   9109.0  2014-02-01 09:08:55
# 4  2014-02-01 09:09:08      30175   6985.0  2014-02-01 09:09:09
#
#      CallDepartureTime
# 0  2014-02-01 09:05:52
# 1  2014-02-01 09:07:00
# 2  2014-02-01 09:09:05
# 3  2014-02-01 09:13:31
# 4  2014-02-01 09:12:55

# %%
callArrival = t["CallArrivalTime"]

# %%
day = []
hour = []

# %%
for i in range(t.shape[0]):
    day.append(callArrival[i].split(" ")[0].split("-")[2])

# %%
day = pd.DataFrame(day, columns=["jour"])

# %%
t["jour"] = day["jour"]

# %%
t['jour'] = t['jour'].astype(int)

# %%
np.unique(t["jour"])
# Out:
# array([ 1,  3,  4,  5,  6,  7,  8, 10, 11, 12, 13, 14, 15, 17, 18, 19, 20,
#        21, 22, 24, 25, 26, 27, 28])

# %%
t[t.jour.isin([1])]
# Out:
#          CallArrivalTime  ServiceID  AgentID         AnsweredTime  \
# 0    2014-02-01 09:00:37      30560   6975.0  2014-02-01 09:00:38
# 1    2014-02-01 09:04:18      30175   6985.0  2014-02-01 09:04:19
# 2    2014-02-01 09:08:43      30175   7531.0  2014-02-01 09:08:44
# 3    2014-02-01 09:08:54      30560   9109.0  2014-02-01 09:08:55
# 4    2014-02-01 09:09:08      30175   6985.0  2014-02-01 09:09:09
# ..                   ...        ...      ...                  ...
# 300  2014-02-01 16:49:59      30175   8866.0  2014-02-01 16:50:00
# 301  2014-02-01 16:52:24      30560   8077.0  2014-02-01 16:52:52
# 302  2014-02-01 16:52:35      30172   8866.0  2014-02-01 16:53:00
# 303  2014-02-01 16:53:34      30560   8866.0  2014-02-01 16:56:40
# 304  2014-02-01 17:00:06      30560      NaN                  NaN
#
#        CallDepartureTime  jour
# 0    2014-02-01 09:05:52     1
# 1    2014-02-01 09:07:00     1
# 2    2014-02-01 09:09:05     1
# 3    2014-02-01 09:13:31     1
# ...

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def get_height_service(path,file_name,save_to):
    if not os.path.exists(save_to):
        os.makedirs(save_to)
    call1_ = pd.read_csv(path+"/"+ file_name)
    call_used_var_ = ["date_received","queue_name","agent_number","answered","hangup"]
    call_new_col_ = ["CallArrivalTime","ServiceID","AgentID","AnsweredTime","CallDepartureTime"]
    call_1_ = call1[call_used_var_]
    call_1_.columns = call_new_col_
    #On recupere les 8 services demandes
    height_services = list(call_1_['ServiceID'].value_counts().index)[:8]
    boolean_series = call_1_.ServiceID.isin(height_services)
    call_1_ = call_1_[boolean_series]
    call_1_.to_csv(save_to+"/"+file_name,index=False)
    

    
#Count the number of agent with a specific service in the day
def count_agent_with_service(service_id,agent_dict):
    number_of_agent = 0
    for key, value in agent_dict.items():
        if service_id in value:
            number_of_agent+=1
    return number_of_agent

def get_list_service_agent_day(agent_id,data_call_day):
    data = data_call_day[data_call_day['AgentID']==agent_id] 
    services  = np.unique(list(data['ServiceID']))
    return services

def set_the_number_of_agent(dataCall):
    dataCall = dataCall.reset_index().drop('index',axis=1)
    #get the list of agent 
    list_of_agent = np.unique(list(dataCall['AgentID']))
    #get the dictionnary agent_id, list_of_services
    agent_dict = {}
    #Store the number of agent inside the list
    number_of_agent = []
    for agent in list_of_agent:
        agent_dict[agent] = get_list_service_agent_day(agent,dataCall)
#     print(agent_dict)
    for i in range(dataCall.shape[0]):
        service = dataCall['ServiceID'][i]
        #Get the number of agent that have the service id
        n_agent = count_agent_with_service(service,agent_dict)
        #Store in the list
        number_of_agent.append(n_agent)
#     print(dataCall.shape[0],len(number_of_agent))
    dataCall["number_of_agent"] = np.array(number_of_agent)
    
    return dataCall

def split_by_day(filename,path,save_to):
    if not os.path.exists(save_to+"/"+filename.split(".")[0]):
        os.makedirs(save_to+"/"+filename.split(".")[0])
        
    #split by day now
    data = pd.read_csv(path+ "/"+filename)
    callArrival = data["CallArrivalTime"]
    day = []
    hour = []
    for i in range(data.shape[0]):
        day.append(callArrival[i].split(" ")[0].split("-")[2])
    day = pd.DataFrame(day, columns=["jour"])
    data["jour"] = day["jour"]
    data['jour'] = data['jour'].astype(int)
    for i in list(np.unique(t["jour"])):
        final = t[t.jour.isin([i])]
        final[['ServiceID','AgentID']] = final[['ServiceID','AgentID']].fillna(value=0)
        final[['CallArrivalTime','AnsweredTime','CallDepartureTime']] = final[['CallArrivalTime','AnsweredTime','CallDepartureTime']].fillna(value="0000-00-00 00:00:00")
        ###
        
        final = set_the_number_of_agent(final)
        #
        ###
        final.drop("jour",axis=1).fillna("NULL").to_csv(save_to+"/"+filename.split(".")[0]+"/"+str(i)+".csv",index=False)

# %%
for name in filenames:
    split_by_day(name,"FinalData","nouveau")
# Out:
# /home/motall/.local/lib/python3.8/site-packages/pandas/core/frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /home/motall/.local/lib/python3.8/site-packages/pandas/core/frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /home/motall/.local/lib/python3.8/site-packages/pandas/core/frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# !ls
# Out:
#  calls-2014-01		      datasets	  Tp_HomeWork-1.R
#  calls-2014-02.csv	      f		  TravailFinalDIC2.pdf
#  calls-2014-02.csvfinal       FinalData  'Untitled Folder'
#  calls-2014-02.csvfinal.csv   nouveau	  Untitled.ipynb
#  cours			      thesis

# %%
# !ls
# Out:
#  calls-2014-01		      datasets	  Tp_HomeWork-1.R
#  calls-2014-02.csv	      f		  TravailFinalDIC2.pdf
#  calls-2014-02.csvfinal       FinalData  'Untitled Folder'
#  calls-2014-02.csvfinal.csv   nouveau	  Untitled.ipynb
#  cours			      thesis

# %%
d = pd.DataFrame([[1,2,3],[4,6,8]],columns=["a","b","c"])

# %%
d
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  6  8

# %%
d.drop("a",axis=1)
# Out:
#    b  c
# 0  2  3
# 1  6  8

# %%
act_
# Out:
#               id  startdatetime    enddatetime  agent_id
# 0       20015827   1/2/14 07:18   1/2/14 08:00      8189
# 1       20015849   1/2/14 07:41   1/2/14 08:00      8076
# 2       20015856   1/2/14 07:46   1/2/14 07:59      6968
# 3       20015861   1/2/14 07:48   1/2/14 08:00      9423
# 4       20015866   1/2/14 07:50   1/2/14 08:00      8861
# ...          ...            ...            ...       ...
# 140701  20722418  1/31/14 19:43  1/31/14 20:00      8494
# 140702  20722720  1/31/14 20:00  1/31/14 20:00      8494
# 140703  20722723  1/31/14 20:00  1/31/14 20:00      6932
# 140704  20723816  1/31/14 21:46  1/31/14 21:46      6925
# 140705  20723910  1/31/14 21:46  1/31/14 22:15      6925
#
# [140706 rows x 4 columns]

# %%
act_ = act_1.copy()

# %%
act_["startdatetime"][0].split(" ")[0].split("/")[1]
# Out:
# '2'

# %%
act1 = pd.read_csv(data_path+"/activity-2014-01.csv")

# %%
output = split_act(act1)
output
# Out:
#              id  startdatetime    enddatetime  agent_id  jour
# 0      20015891   1/2/14 07:58   1/2/14 08:18      6935     2
# 1      20015900   1/2/14 07:59   1/2/14 08:16      6940     2
# 2      20015903   1/2/14 07:59   1/2/14 08:20      9424     2
# 3      20015904   1/2/14 07:59   1/2/14 08:21      6968     2
# 4      20015908   1/2/14 08:00   1/2/14 08:14      9423     2
# ...         ...            ...            ...       ...   ...
# 65148  20722093  1/31/14 19:21  1/31/14 19:29      8494    31
# 65149  20722195  1/31/14 19:29  1/31/14 19:34      8494    31
# 65150  20722292  1/31/14 19:35  1/31/14 19:41      8494    31
# 65151  20722390  1/31/14 19:41  1/31/14 19:43      8494    31
# 65152  20722418  1/31/14 19:43  1/31/14 20:00      8494    31
#
# [65153 rows x 5 columns]

# %%
#Count the number of agent with a service
def count_agent_with_service(service_id,agent_dict):
    number_of_agent = 0
    for key, value in agent_dict.items():
        if service_id in value:
            number_of_agent+=1
    return number_of_agent

# %%
def set_the_number_of_agent():
    #data call
    data_call_day_ = pd.read_csv("nouveau/calls-2014-01/1.csv")
    #get the list of agent 
    list_of_agent = np.unique(list(data_call_day_['AgentID']))
    #get the dictionnary agent_id, list_of_services
    agent_dict = {}
    #Store the number of agent inside the list
    number_of_agent = []
    for agent in list_of_agent:
        agent_dict[agent] = get_list_service_agent_day(agent,data_call_day_)
        
    for i in range(data_call_day_.shape[0]):
        service = data_call_day_['ServiceID'][i]
        #Get the number of agent that have the service id
        n_agent = count_agent_with_service(service,agent_dict)
        #Store in the list
        number_of_agent.append(n_agent)
    data_call_day_["number_of_agent"] = np.array(number_of_agent)
    
    return data_call_day_

# %%
set_the_number_of_agent()
# Out:
#          CallArrivalTime  ServiceID  AgentID         AnsweredTime  \
# 0    2014-02-01 09:00:37      30560   6975.0  2014-02-01 09:00:38
# 1    2014-02-01 09:04:18      30175   6985.0  2014-02-01 09:04:19
# 2    2014-02-01 09:08:43      30175   7531.0  2014-02-01 09:08:44
# 3    2014-02-01 09:08:54      30560   9109.0  2014-02-01 09:08:55
# 4    2014-02-01 09:09:08      30175   6985.0  2014-02-01 09:09:09
# ..                   ...        ...      ...                  ...
# 300  2014-02-01 16:49:59      30175   8866.0  2014-02-01 16:50:00
# 301  2014-02-01 16:52:24      30560   8077.0  2014-02-01 16:52:52
# 302  2014-02-01 16:52:35      30172   8866.0  2014-02-01 16:53:00
# 303  2014-02-01 16:53:34      30560   8866.0  2014-02-01 16:56:40
# 304  2014-02-01 17:00:06      30560      0.0  0000-00-00 00:00:00
#
#        CallDepartureTime  number_of_agent
# 0    2014-02-01 09:05:52               13
# 1    2014-02-01 09:07:00               13
# 2    2014-02-01 09:09:05               13
# ...

# %%
np.unique(set_the_number_of_agent()['number_of_agent'])
# Out:
# array([ 4,  9, 13])
